# %% [markdown]
# # Clustering Merch Data Shirts
# 1. remove texts that pop up in all documents (i.e. stopwords / phrases)
# 2. clean the documents
# 3. stem the words in each document

# %% [markdown]
# ## Initialize steps

# %% [markdown]
# First we import the necessary libraries.

# %%
import numpy as np
import pandas as pd
import nltk
from bs4 import BeautifulSoup
import re
import os
import codecs
from sklearn import feature_extraction
import mpld3

# %% [markdown]
# Now we import the shirt data file and create documents from it. Each document is the title of the shirt followed by it's description.

# %%
def read_shirt_data_file(path):
    documents = []
    asins = []
    with open(path, 'r') as data_file:
        for line in data_file:
            document = line.split('|')
            title = document[2].split(":",1)[1]
            description = document[10].split(":",1)[1]
            replace_1 = "Lightweight, Classic fit, Double-needle sleeve and bottom hem"
            replace_2 = "Solid colors: 100% Cotton; Heather Grey: 90% Cotton, 10% Polyester; All Other Heathers: 50% Cotton, 50% Polyester Imported Machine wash cold with like colors, dry low heat "
            description = description.replace(replace_1, '').replace(replace_2,'')
            documents.append(title + '. ' + description)
            asins.append(document[1].split(":")[1])
    return documents, asins

documents, asins = read_shirt_data_file("shirts_featured_small")
print(documents[0])
# Out:
# Marvel Avengers Endgame Movie Logo Graphic T-Shirt. Officially Licensed Marvel Tee Shirt 18MARF00471A

# %%
print(documents)

# %% [markdown]
# Clean the documents to make them unicode.

# %%
def clean_documents(documents):
    documents_clean = []
    for text in documents:
        text = BeautifulSoup(text, 'html.parser').getText()
        documents_clean.append(text)

    return documents_clean

documents = clean_documents(documents)

# %%
print(documents)
# Out:
# ['Marvel Avengers Endgame Movie Logo Graphic T-Shirt. Officially Licensed Marvel Tee Shirt 18MARF00471A \n', 'Marvel Studios MORE THAN A FAN 2019 Graphic T-Shirt. Officially Licensed Marvel T-Shirt; This listing will be updated as Marvel movies are released. 17MARF00273A-001 18MARF00017A-001 \n', 'Autism Awareness Tshirt Kindness Puzzle Ribbon Heart T-Shirt. This Be Kind Shirt is perfect for Autism Awareness Month to show love for the kids with autistic spectrum or behavior disorder. \n', 'Shane Dawson Oh My God Pig T-Shirt. Official Licensed Fan Art Designed by GSM Studio \n', 'Marvel Avengers Infinity War Neon Team Graphic T-Shirt. Officially Licensed Marvel Tee Shirt 17MARL00099A \n', 'I See Your True Colors Hands Autism Awareness Tshirt. Autism Awareness T shirt - Autism Awareness Shirt - autism gift shirt - autism shirts - autism products - aureness stickers - autism ring - autism dad shirt- autism mom shirt - autism shirt for kids - shirt for kids with autism - Autism Awareness tee Autism TShirt - autistic gift shirt - autistic toys for toddlers - autistic toys for girls - books autism - children books about autism - autism awareness products - autism puzzle piece shirt - autism speaks sticker - autism adults shirt \n', 'Kids Pinkfong Baby Shark Official T-shirt. Original Pinkfong Baby Shark merchandise \n', 'Marvel Avengers Endgame Movie Poster Graphic T-Shirt. Officially Licensed Marvel Avengers Endgame Tee Shirt 18MARF00754A \n', 'Marvel Ultimate Periodic Table Of Elements Graphic T-Shirt. Officially Licensed Marvel Apparel 18MARV00081A \n', 'Autism Awareness Bee Kind Puzzle Pieces T Shirt. Bumble bee supports being kind to everyone and loving all people. This bumble bee also happens to be sporting the Autism awareness puzzle pieces for families and people who love a child who is autistic Gift idea for your mother, father, grandfather, grandmother, daughter, sister, brother, kid, significant other, partner, or spouse. Holiday presents are perfect. \n', "Don't Make Me Add You To List Medieval-Throne Style Tshirt. Perfect for fans of cosplay, games, Medieval-reminiscent fanfiction, streaming your favorite tv shows, and medieval thrones & decor. This easy, festive, witty, clever, comfy shirt is perfect for any season. Makes a great Christmas present. Christmas is coming soon! Makes a great gift for people who binge watch TV and are love shows set back in the olden times. Great t-shirt this season! \n", 'see the able not the label shirt cute autism awareness. see the able not the label shirt cute autism awareness This cute autism awareness t-shirt is also great for Anniversary gift ideas, birthday, mothers day, fathers day, Thanksgiving, Christmas, or Halloween. \n', "Love Ribbon Heart Puzzle Autism Awareness Gift Shirt. If you want Autism T-shirt for teachers, autism mom, autism apparel, autism brother, autistic brother then this long sleeve is just a cute gift for your loved ones. Pair it up with autism toys, bracelet, bags, charm and ribbon. Complete collection of World Autism Awareness Day accessories for him/ her (card, gifts, pajamas, decoration, hoodie, tank top, outfit, coffee mug). Perfect gifts for Birthday, Christmas, Father's Day, Mother's Day, Grandparent's Day, Christmas, Autism Day \n", 'Happy Eastrawr T Rex Dinosaur Easter Bunny Egg Shirt Kids. This funny Happy Eastrawr T Rex dinosaur shirt features a T Rex dinosaur dressed as the Easter bunny holding an chocolate Easter egg and makes the perfect Easter Day shirt for boys, girls, kids, men, women, Easter bunny or dinosaur lovers of any age. This funny Happy Easter dinosaur shirt is sure to be a hit on Easter day. Gather your Easter eggs in style with this funny Easter dinosaur shirts for boys. Makes a great birthday gift or Easter gift too. Get your funny T Rex dinosaur Easter bunny shirt. \n', "50th Birthday T Shirt Gift Vintage 1969 Classic Men Women. Celebrate your 50th birthday because you're vintage, original, and a legend. This 1969 50th Birthday shi ...

# %% [markdown]
# Import the stemmer and then tokenize and stem the text.

# %%
# load nltk's SnowballStemmer as variabled 'stemmer'
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if not re.search('[^a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if not re.search('[^a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

totalvocab_stemmed = []
totalvocab_tokenized = []
for i in documents:
    allwords_stemmed = tokenize_and_stem(i)
    totalvocab_stemmed.extend(allwords_stemmed)
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)
    
# vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)

# %% [markdown]
# ## Tf-idf and document similarity (normal cosine similarity)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_df=0.6, max_features=200000,
                                 min_df=0.01, stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

# %time tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
print(tfidf_matrix)
print(tfidf_matrix.shape)

terms = tfidf_vectorizer.get_feature_names()
print(len(terms))
print(terms[3125])
print(terms[2893])
print(terms[3468])
print(terms[2311])
print(stemmed_documents[0])

print(terms)

from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(tfidf_matrix)

print(dist)
# Out:
# CPU times: user 153 ms, sys: 6.82 ms, total: 160 ms
# Wall time: 159 ms
#   (0, 3125)	0.17119698825914462
#   (0, 2893)	0.18378492949236733
#   (0, 3468)	0.15277823708007066
#   (0, 2311)	0.14906628625907903
#   (0, 2935)	0.21181519699392454
#   (0, 3333)	0.24653384022721284
#   (0, 1671)	0.24653384022721284
#   (0, 422)	0.21181519699392454
#   (0, 3099)	0.21181519699392454
#   (0, 4906)	0.13120100385418146
#   (0, 3124)	0.17119698825914462
#   (0, 2889)	0.15277823708007066
#   (0, 3463)	0.13120100385418146
#   (0, 2310)	0.14906628625907903
#   (0, 2934)	0.21181519699392454
#   (0, 3332)	0.24653384022721284
#   (0, 1670)	0.21181519699392454
#   (0, 421)	0.21181519699392454
#   (0, 3098)	0.20063829032075803
#   (0, 4871)	0.09285993335263241
#   (0, 2880)	0.13120100385418146
#   (0, 3456)	0.11258997445657215
#   (0, 2308)	0.12642706806978748
#   (0, 2933)	0.20063829032075803
#   (0, 3325)	0.17119698825914462
#   :	:
#   (99, 3467)	0.18594361301051954
#   (99, 5253)	0.18594361301051954
#   (99, 1517)	0.18594361301051954
#   (99, 3586)	0.18594361301051954
#   (99, 2663)	0.18594361301051954
#   (99, 3584)	0.18594361301051954
#   (99, 2887)	0.18594361301051954
#   (99, 1516)	0.18594361301051954
#   (99, 3585)	0.18594361301051954
#   (99, 2661)	0.3718872260210391
#   (99, 3583)	0.3718872260210391
#   (99, 2660)	0.3718872260210391
#   (99, 5252)	0.1706258447090165
#   (99, 1502)	0.12912217853778868
#   (99, 5225)	0.10293628066806386
#   (99, 184)	0.11523017434792843
#   (99, 2311)	0.11243050373744985
#   (99, 2935)	0.1597577151407947
#   (99, 3463)	0.09895594318722954
#   (99, 2310)	0.11243050373744985
#   (99, 2934)	0.1597577151407947
#   (99, 2880)	0.09895594318722954
#   (99, 3456)	0.08491891668876964
#   (99, 2308)	0.09535528995758648
#   (99, 2933)	0.15132773892667917
# (100, 5482)
# 5482
# marvel tee shirt
# licen marvel tee
# offici licen marvel
# graphic offici licen
# marvel aveng endgam movi logo graphic offici licens marvel tee shirt
# ['abl', 'abl label', 'abl label shirt', 'accept', 'accept grab', 'accept grab super', 'accept peopl', 'accept peopl autism', 'accept understand', 'accept understand love', 'accessori', 'accessori action', 'accessori action figur', 'accessori card', 'accessori card gift', 'accessori hat', 'accessori hat decor', 'accessori pretti', 'accessori pretti girl', 'accessori suppli', 'accessori suppli earring', 'action', 'action figur', 'action figur collar', 'activ', 'activ love', 'activ love vintag', 'activist', 'activist tinsel', 'activist tinsel mistleto', 'add', 'add list', 'add list style', 'addit', 'addit fisherman', 'addit fisherman jewelri', 'adult', 'adult happi', 'adult happi easter', 'adult perfect', 'adult perfect american', 'adult shirt', 'aerosmith', 'aerosmith collect', 'aerosmith collect aerosmith', 'aerosmith dream', 'aerosmith dream offici', 'aerosmith offici', 'aerosmith offici aerosmith', 'af', 'af tank', 'af tank boxer', 'africa', 'africa know', 'africa know fli', 'african', 'african american', 'african american woman', 'african american women', 'afro', 'afro natur', 'afro natur hair', 'afro tee', 'afro urban', 'afro urban apparel', 'age', 'age funni', 'age funni happi', 'alexandria', 'alexandria la', 'alexandria la shirt', 'alien', 'alien extraterrestri', 'alien extraterrestri believ', 'alien retro', 'alien retro vintag', 'alien shirt', 'alien shirt gift', 'alien tshirt', 'alien tshirt lover', 'alien ufo', 'alien ufo loser', 'alien vintag', 'alien vintag shirt', 'alleg', 'alleg ostrich', 'alleg ostrich gift', 'alleg ostrich shirt', 'alleg shirt', 'alleg shirt alleg', 'alumni', 'alumni new', 'alumni new colleg', 'amend', 'amend donald', 'amend donald trump', 'amend t', 'amend t shirt', 'america', 'america funni', 'america funni conserv', 'american', 'american flag', 'american flag autism', 'american flag distress', 'american flag fish', 'american lacross', 'american lacross shirt', 'american lax', 'american lax lacross', 'american woman', 'american woman natur', 'american women', 'american women embrac', 'ani', 'ani age', 'ani age funni', 'ani alien', 'ani alien extraterrestri', 'ani gift', 'ani gift occa', 'ani liber', 'ani liber democrat', 'ani month', 'ani month birthday', 'ani season', 'ani season make', 'ani strong', 'ani strong autism', 'ani team', 'ani team sport', 'anim', 'anim best', 'anim best cat', 'anim offici', 'anim offici licen', 'anim right', 'anim right activist', 'anim surviv', 'anim surviv great', 'anniversari', 'anniversari gift', 'anniversari gift idea', 'anniversari present', 'anniversari present fan', 'anniversari tee', 'anniversari valentin', 'anniversari valentin day', 'anon', 'anon breadcrumb', 'anon breadcrumb great', 'anon follow', 'anon follow love', 'anon know', 'anon know storm', 'anon origin', 'anon origin t', 'anon post', 'anon post coincid', 'anybodi', 'anybodi famili', 'anybodi famili dad', 'anymor', 'anymor funni', 'anymor funni retir', 'anymor tshirt', 'anymor tshirt funni', 'anyon', 'anyon america', 'anyon america funni', 'anyon autism', 'anyon conspiraci', 'anyon conspiraci believ', 'anyon love', 'anyon love live', 'anyon spectrum', 'anyon spectrum complet', 'anyon support', 'anyon support autism', 'anyth', 'anyth kind', 'anyth kind autism', 'anyth wear', 'anyth wear shirt', 'apparel', 'apparel ani', 'apparel ani month', 'apparel autism', 'apparel autism awar', 'apparel autism brother', 'apparel autism mom', 'apparel charm', 'apparel charm crown', 'apparel great', 'apparel great fun', 'apparel t', 'apparel t shirt', 'apparel vintag', 'apparel vintag logo', 'appreci', 'appreci gift', 'appreci gift special', 'april', 'april asd', 'april asd birthday', 'april june', 'april june juli', 'april nation', 'april nation autism', 'april shirt', 'april shirt autism', 'april support', 'april support parent', 'ar', 'ar ca', 'ar ca sm', 'arch', 'arch logo', 'arch logo men', 'art', 'art design', 'art design gsm', 'artwork', 'asd', 'asd birthday', 'asd birthday present', 'aster', 'aster rosem ...
# [[ 2.22044605e-16  7.55189388e-01  1.00000000e+00 ...  9.84584264e-01
#    1.00000000e+00  8.20857696e-01]
#  [ 7.55189388e-01 -2.22044605e-16  1.00000000e+00 ...  1.00000000e+00
#    1.00000000e+00  9.34934649e-01]
#  [ 1.00000000e+00  1.00000000e+00 -4.44089210e-16 ...  1.00000000e+00
#    1.00000000e+00  1.00000000e+00]
#  ...
#  [ 9.84584264e-01  1.00000000e+00  1.00000000e+00 ...  3.33066907e-16
#    1.00000000e+00  9.70046138e-01]
#  [ 1.00000000e+00  1.00000000e+00  1.00000000e+00 ...  1.00000000e+00
#   -2.22044605e-16  1.00000000e+00]
#  [ 8.20857696e-01  9.34934649e-01  1.00000000e+00 ...  9.70046138e-01
#    1.00000000e+00 -2.22044605e-16]]
# /usr/local/anaconda3/envs/niche_finder/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %% [markdown]
# ### Soft Cosine Similarity

# %%
import gensim
# upgrade gensim if you can't import softcossim
from gensim.matutils import softcossim 
from gensim import corpora
import gensim.downloader as api
from gensim.utils import simple_preprocess
print(gensim.__version__)
#> '3.6.0'

# Download the FastText model
og_fasttext_model300 = api.load('fasttext-wiki-news-subwords-300')
print("done")
# Out:
# 3.4.0
# done

# %%
print(documents[0])
# Out:
# Marvel Avengers Endgame Movie Logo Graphic T-Shirt. Officially Licensed Marvel Tee Shirt 18MARF00471A

# %%
stemmed_documents = [" ".join(tokenize_and_stem(document)) for document in documents ]
print(stemmed_documents[0])
print(simple_preprocess(documents[0]))
# Out:
# marvel aveng endgam movi logo graphic offici licens marvel tee shirt
# ['marvel', 'avengers', 'endgame', 'movie', 'logo', 'graphic', 'shirt', 'officially', 'licensed', 'marvel', 'tee', 'shirt', 'marf']

# %%
# Prepare a dictionary and a corpus.
dictionary = corpora.Dictionary(stemmed_documents)
print(dictionary)
# Prepare the similarity matrix
similarity_matrix = fasttext_model300.similarity_matrix(dictionary, tfidf=None, threshold=0.0, exponent=2.0, nonzero_limit=100)
print(similarity_matrix)
# Convert the sentences into bag-of-words vectors.
sent_1 = dictionary.doc2bow(simple_preprocess(documents[0]))
print(sent_1)
# Out:
# Dictionary(844 unique tokens: ['aveng', 'endgam', 'graphic', 'licens', 'logo']...)
#   (0, 0)	1.0
#   (1, 1)	1.0
#   (2, 2)	1.0
#   (87, 2)	0.29002804
#   (513, 2)	0.39525434
#   (3, 3)	1.0
#   (4, 4)	1.0
#   (364, 4)	0.3381835
#   (367, 4)	0.30361277
#   (421, 4)	0.3721742
#   (422, 4)	0.2973664
#   (476, 4)	0.53717667
#   (511, 4)	0.38052085
#   (575, 4)	0.36415815
#   (620, 4)	0.31270242
#   (76, 4)	0.24808821
#   (5, 5)	1.0
#   (137, 5)	0.353291
#   (734, 5)	0.24536575
#   (6, 6)	1.0
#   (7, 7)	1.0
#   (8, 8)	1.0
#   (43, 8)	0.549481
#   (180, 8)	0.39647278
#   (197, 8)	0.36107263
#   :	:
#   (270, 833)	0.3811983
#   (381, 833)	0.37798473
#   (834, 834)	1.0
#   (835, 835)	1.0
#   (836, 836)	1.0
#   (38, 836)	0.3020304
#   (56, 836)	0.3202309
#   (64, 836)	0.4149798
#   (343, 836)	0.5361713
#   (414, 836)	0.8350328
#   (568, 836)	0.33491045
#   (645, 836)	0.6516957
#   (697, 836)	0.34693995
#   (768, 836)	0.566946
#   (837, 837)	1.0
#   (410, 837)	0.20215365
#   (622, 837)	0.4176403
#   (838, 838)	1.0
#   (839, 839)	1.0
#   (840, 840)	1.0
#   (560, 840)	0.4419296
#   (841, 841)	1.0
#   (842, 842)	1.0
#   (843, 843)	1.0
#   (540, 843)	0.34785533
# [(2, 1), (4, 1), (5, 2), (8, 2), (9, 1)]

# %%
print(dictionary.token2id)
# Out:
# {'aveng': 0, 'endgam': 1, 'graphic': 2, 'licens': 3, 'logo': 4, 'marvel': 5, 'movi': 6, 'offici': 7, 'shirt': 8, 'tee': 9, 'a': 10, 'are': 11, 'as': 12, 'be': 13, 'fan': 14, 'list': 15, 'more': 16, 'releas': 17, 'studio': 18, 'than': 19, 'this': 20, 'updat': 21, 'will': 22, 'autism': 23, 'autist': 24, 'awar': 25, 'behavior': 26, 'disord': 27, 'for': 28, 'heart': 29, 'is': 30, 'kid': 31, 'kind': 32, 'love': 33, 'month': 34, 'or': 35, 'perfect': 36, 'puzzl': 37, 'ribbon': 38, 'show': 39, 'spectrum': 40, 'the': 41, 'to': 42, 'tshirt': 43, 'with': 44, 'art': 45, 'by': 46, 'dawson': 47, 'design': 48, 'god': 49, 'gsm': 50, 'my': 51, 'oh': 52, 'pig': 53, 'shane': 54, 'infin': 55, 'neon': 56, 'team': 57, 'war': 58, 'about': 59, 'adult': 60, 'aur': 61, 'book': 62, 'children': 63, 'color': 64, 'dad': 65, 'gift': 66, 'girl': 67, 'hand': 68, 'i': 69, 'mom': 70, 'piec': 71, 'product': 72, 'ring': 73, 'see': 74, 'speak': 75, 'sticker': 76, 't': 77, 'toddler': 78, 'toy': 79, 'true': 80, 'your': 81, 'babi': 82, 'merchandis': 83, 'origin': 84, 'pinkfong': 85, 'shark': 86, 'poster': 87, 'apparel': 88, 'element': 89, 'of': 90, 'period': 91, 'tabl': 92, 'ultim': 93, 'all': 94, 'also': 95, 'and': 96, 'bee': 97, 'brother': 98, 'bumbl': 99, 'child': 100, 'daughter': 101, 'everyon': 102, 'famili': 103, 'father': 104, 'grandfath': 105, 'grandmoth': 106, 'happen': 107, 'holiday': 108, 'idea': 109, 'mother': 110, 'other': 111, 'partner': 112, 'peopl': 113, 'present': 114, 'signific': 115, 'sister': 116, 'sport': 117, 'spous': 118, 'support': 119, 'who': 120, 'add': 121, 'ani': 122, 'back': 123, 'bing': 124, 'christma': 125, 'clever': 126, 'come': 127, 'comfi': 128, 'cosplay': 129, 'decor': 130, 'do': 131, 'easi': 132, 'fanfict': 133, 'favorit': 134, 'festiv': 135, 'game': 136, 'great': 137, 'in': 138, 'make': 139, 'me': 140, 'mediev': 141, 'olden': 142, 'season': 143, 'set': 144, 'soon': 145, 'stream': 146, 'style': 147, 'throne': 148, 'time': 149, 'tv': 150, 'watch': 151, 'witti': 152, 'you': 153, 'abl': 154, 'anniversari': 155, 'birthday': 156, 'cute': 157, 'day': 158, 'halloween': 159, 'label': 160, 'not': 161, 'thanksgiv': 162, 'accessori': 163, 'bag': 164, 'bracelet': 165, 'card': 166, 'charm': 167, 'coffe': 168, 'collect': 169, 'complet': 170, 'grandpar': 171, 'her': 172, 'hoodi': 173, 'if': 174, 'it': 175, 'just': 176, 'long': 177, 'mug': 178, 'one': 179, 'outfit': 180, 'pair': 181, 'pajama': 182, 'sleev': 183, 'tank': 184, 'teacher': 185, 'then': 186, 'top': 187, 'up': 188, 'want': 189, 'world': 190, 'age': 191, 'an': 192, 'boy': 193, 'bunni': 194, 'chocol': 195, 'dinosaur': 196, 'dress': 197, 'easter': 198, 'eastrawr': 199, 'egg': 200, 'featur': 201, 'funni': 202, 'gather': 203, 'get': 204, 'happi': 205, 'hit': 206, 'hold': 207, 'lover': 208, 'men': 209, 'on': 210, 'rex': 211, 'sure': 212, 'too': 213, 'women': 214, 'april': 215, 'august': 216, 'awesom': 217, 'becaus': 218, 'celebr': 219, 'classic': 220, 'cool': 221, 'decemb': 222, 'distress': 223, 'februari': 224, 'fiftieth': 225, 'font': 226, 'husband': 227, 'januari': 228, 'juli': 229, 'june': 230, 'legend': 231, 'march': 232, 'may': 233, 'novemb': 234, 'octob': 235, 'retro': 236, 'scheme': 237, 'septemb': 238, 'simpl': 239, 'vintag': 240, 'wife': 241, 'captain': 242, 'galaxi': 243, 'goos': 244, 'portrait': 245, 'cast': 246, 'first': 247, 'full': 248, 'ten': 249, 'year': 250, 'anyon': 251, 'anyth': 252, 'aunt': 253, 'can': 254, 'eleph': 255, 'fighter': 256, 'give': 257, 'occas': 258, 'son': 259, 'sunflow': 260, 'uncl': 261, 'warrior': 262, 'where': 263, 'yourself': 264, 'quot': 265, 'mommi': 266, 'best': 267, 'from': 268, 'insid': 269, 'know': 270, 'let': 271, 'look': 272, 'made': 273, 'member': 274, 'nice': 275, 'tell': 276, 'that': 277, 'wear': 278, 'word': 279, 'dure': 280, 'everi': 281, 'friend': 282, 'nation': 283, 'onli': 284, 'parent': 285, 'relat': 286, 'shield': 287, 'superhero': 288, 'their': 289, 'accept': 290, 'understand': 291, 'appreci': 292, 'asd': 293, 'ed': 294, 'educ': 295,  ...

# %%
print(similarity_matrix[7])
# Out:
#   (0, 7)	1.0

# %%
sent_1 = dictionary.doc2bow(simple_preprocess(documents[0]))
print(sent_1)
sent_2 = dictionary.doc2bow(simple_preprocess(documents[16]))
print(documents[0])
print(documents[18])
print(softcossim(sent_1, sent_2, similarity_matrix))

# %% [markdown]
# ## K-means clustering

# %% [markdown]
# K-means isn't necessarily the best. You must initialize with a pre-determined number of clusters

# %%
from sklearn.cluster import KMeans

num_clusters = 5

km = KMeans(n_clusters=num_clusters)

# %time km.fit(tfidf_matrix)

clusters = km.labels_.tolist()

# %% [markdown]
# ## Hierarchial document clustering

# %%
from scipy.cluster.hierarchy import ward, dendrogram
import matplotlib.pyplot as plt


linkage_matrix = ward(dist) #define the linkage_matrix using ward clustering pre-computed distances

fig, ax = plt.subplots(figsize=(15, 20)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=asins);

plt.tick_params(\
    axis= 'x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

#uncomment below to save figure
plt.savefig('ward_clusters.png', dpi=200) #save figure as ward_clusters
